# %% [markdown]
# ## Washington State Liquor and Cannabis Board (WSLCB) Open Data Portal
#
# *For an introduction to the WSLCB, [see the README in the parent directory](../README.md).*
#
# *For an introduction to the WSLCB's Socrata-based Open Data Portal, [see the README in this directory](./README.md).*
#
# ### Dataset: Licensed Businesses
#
# * Canonical Dataset ID: **bhbp-x4eb**
# * Detail screen on the WSLCB Portal: https://data.lcb.wa.gov/Licensing/Licensed-Businesses/u3zh-ri66
# * Detail screen on Socrata's Open Data Foundry: https://dev.socrata.com/foundry/data.lcb.wa.gov/bhbp-x4eb
#
# We'll be using the [`cannapy`](https://github.com/CannabisData/cannapy) library to access the portal data.  `cannapy` aims to provide an abstract interface for accessing and working with *Cannabis* data from around the world.  It utilizes [xmunoz](https://github.com/xmunoz)'s [`sodapy`](https://github.com/xmunoz/sodapy) client to access Socrata-based open data portals and can return data loaded into [Pandas DataFrames](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html).

# %%
import time
import cannapy.us.wa.wslcb.portal as wslcb
import pandas as pd

# %%
# Specify your own Socrata App Token if you plan to experiment
app_token = 'XaB9MBqc81C3KT4Vps6Wh5LZt'

# Instantiate a cannapy interface to the WSLCB open data portal
portal = wslcb.WSLCBPortal(app_token)

# We'll be using the Licensed Businesses dataset
dataset_id = 'bhbp-x4eb'

# %%
# Check when the dataset was last updated
last_updated = portal.dataset_last_updated(dataset_id)
print('Last updated: {}'.format(time.strftime('%c', last_updated)))
# Out:
# Last updated: Mon Nov 13 12:35:56 2017

# %%
# Retrieve the dataset preloaded into a Pandas DataFrame
df = portal.get_dataframe(dataset_id)

# Validate we've got the right data by examining the first few rows
df.head()
# Out:
#   license                                              type createdate  \
# 0  362444                                MARIJUANA RETAILER   20170105
# 1  421568  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT   20171108
# 2  412051                         MARIJUANA PRODUCER TIER 3   20170905
# 3  412698                         MARIJUANA PRODUCER TIER 1   20170817
# 4  417880  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT   20161117
#
#             active                organization                       address  \
# 0  ACTIVE (ISSUED)                      V.S.W.                   13014 WA-99
# 1  ACTIVE (ISSUED)                     BUD HUT           1717 NE ANDRESEN RD
# 2  ACTIVE (ISSUED)                    SOLSTICE              640 S SPOKANE ST
# 3  ACTIVE (ISSUED)         COOKIE CUTTER FARMS  23410 HIDDEN VALLEY RD STE A
# 4  ACTIVE (ISSUED)  LEGAL MARIJUANA SUPERSTORE             3610 BETHEL RD SE
#
#   address_line_2           city state        zip     county    dayphone  \
# 0            NaN        EVERETT    WA  982040000  SNOHOMISH  2062715468
# 1            NaN      VANCOUVER    WA  986616890      CLARK  4257896996
# 2        SUITE B        SEATTLE    WA  981342225       KING  4252838841
# 3            NaN  GRANITE FALLS    WA  982523600  SNOHOMISH  2532312995
# 4      SUITE 100   PORT ORCHARD    WA  983670000     KITSAP  3603401009
#
#                 ubi
# 0  6035684740010001
# 1  6035481120010003
# 2  6031327110010003
# 3  6040431000010001
# 4  6033573230010003

# %%
# The DataFrame value_counts() histogramming method is useful for asking basic questions of any dataset
# column/Series with consistent text values.

# Question: How many licenses have been issued for each business type?
df.type.value_counts()
# Out:
# MARIJUANA PRODUCER TIER 2/MARIJUANA PROCESSOR       245
# MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT    242
# MARIJUANA PRODUCER TIER 3/MARIJUANA PROCESSOR       196
# MARIJUANA PRODUCER TIER 1/MARIJUANA PROCESSOR       107
# MARIJUANA PROCESSOR                                  94
# MARIJUANA PRODUCER TIER 3                            38
# MARIJUANA PRODUCER TIER 2                            30
# MARIJUANA RETAILER                                   27
# MARIJUANA PRODUCER TIER 1                            12
# MARIJUANA TRANSPORTATION                              9
# Name: type, dtype: int64

# %%
# Question: How many licenses are active vs. pending?
df.active.value_counts()
# Out:
# ACTIVE (ISSUED)     898
# PENDING (ISSUED)    102
# Name: active, dtype: int64

# %%
# Question: How many licenses are have been issued per county?
df.county.value_counts()
# Out:
# KING            117
# SPOKANE         106
# SNOHOMISH        98
# OKANOGAN         64
# THURSTON         57
# WHATCOM          49
# PIERCE           48
# BENTON           40
# GRANT            38
# YAKIMA           35
# SKAGIT           28
# CLARK            28
# CHELAN           25
# MASON            25
# GRAYS HARBOR     24
# COWLITZ          21
# STEVENS          21
# ADAMS            18
# PACIFIC          18
# KITSAP           17
# CLALLAM          16
# KLICKITAT        13
# DOUGLAS          12
# WHITMAN          12
# KITTITAS         11
# JEFFERSON        11
# ISLAND            9
# LEWIS             8
# PEND OREILLE      7
# SKAMANIA          5
# LINCOLN           5
# WALLA WALLA       5
# FERRY             2
# WAHKIAKUM         2
# SAN JUAN          2
# ASOTIN            2
# FRANKLIN          1
# Name: county, dtype: int64

# %%
# The UBI column uniquely identifies each licensee, but obscures ownership of multiple licenses by the same entity.
# Let's break that column apart into its constituent parts:
# Unified Business Identifier (UBI): first nine digits
# Business ID Number: next three digits
# Location Number: last four digits
df_v2 = df.rename(columns={'ubi': 'ubi_source'})
df_v2['ubi'] = df_v2.ubi_source.str[0:9]
df_v2['ubi_business_id'] = df_v2.ubi_source.str[9:12]
df_v2['ubi_location'] = df_v2.ubi_source.str[12:]
df_v2.head()
# Out:
#   license                                              type createdate  \
# 0  362444                                MARIJUANA RETAILER   20170105
# 1  421568  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT   20171108
# 2  412051                         MARIJUANA PRODUCER TIER 3   20170905
# 3  412698                         MARIJUANA PRODUCER TIER 1   20170817
# 4  417880  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT   20161117
#
#             active                organization                       address  \
# 0  ACTIVE (ISSUED)                      V.S.W.                   13014 WA-99
# 1  ACTIVE (ISSUED)                     BUD HUT           1717 NE ANDRESEN RD
# 2  ACTIVE (ISSUED)                    SOLSTICE              640 S SPOKANE ST
# 3  ACTIVE (ISSUED)         COOKIE CUTTER FARMS  23410 HIDDEN VALLEY RD STE A
# 4  ACTIVE (ISSUED)  LEGAL MARIJUANA SUPERSTORE             3610 BETHEL RD SE
#
#   address_line_2           city state        zip     county    dayphone  \
# 0            NaN        EVERETT    WA  982040000  SNOHOMISH  2062715468
# 1            NaN      VANCOUVER    WA  986616890      CLARK  4257896996
# 2        SUITE B        SEATTLE    WA  981342225       KING  4252838841
# 3            NaN  GRANITE FALLS    WA  982523600  SNOHOMISH  2532312995
# 4      SUITE 100   PORT ORCHARD    WA  983670000     KITSAP  3603401009
#
#          ubi_source        ubi ubi_business_id ubi_location
# 0  6035684740010001  603568474             001         0001
# 1  6035481120010003  603548112             001         0003
# 2  6031327110010003  603132711             001         0003
# 3  6040431000010001  604043100             001         0001
# 4  6033573230010003  603357323             001         0003

# %%
# Washington law/regulation states a maximum of three Producer/Processor or Retail licenses can be held
# per UBI.  We can validate that by asking: how many licenses are held by any particular UBI?
df_v2.ubi.value_counts().unique()
# Out:
# array([3, 2, 1])

# %%
# Question: How many and what kind of licenses are associated with each UBI?

# Calculate the number of licenses per UBI, and add the Series into a DataFrame for merging
licenses_per_ubi = pd.DataFrame(df_v2.groupby('ubi').size(), columns=['ubi_licenses'])

# Extract context fields from the source DataFrame, merge, and sort
ubi_and_organization = df_v2.loc[:, ['organization', 'type', 'ubi', 'ubi_business_id', 'ubi_location']]
licenses_per_org = pd.merge(ubi_and_organization, licenses_per_ubi, left_on='ubi', right_index=True)
licenses_per_org.sort_values(['ubi_licenses', 'ubi', 'ubi_business_id', 'ubi_location'], ascending=True, inplace=True)
licenses_per_org
# Out:
#                                  organization  \
# 811                         CANNARAIL STATION
# 545                       GREEN HEAD CANNABIS
# 657                             OLIVER'S FARM
# 174                    VASHON ISLAND ORGANICS
# 333                         DUKE'S HILL CANNA
# 406                       ALASKAN GREEN ACRES
# 834                                     JVARD
# 643             APPLICATION SOFTWARE PRODUCTS
# 27                          CAREY INVESTMENTS
# 684                             CALVIN'S BEST
# 57                                GIVING TREE
# 686                          HILL TOP GROWERS
# 540                    GRASSROOTS BAKE SHOPPE
# 168                            MEDICINE WOMAN
# 827                              ANCIENT HERB
# 195                              TWO BROTHERS
# 985                        MARIJUANA AND MORE
# 542  ROYAL CANNABIS PRODUCTION AND PROCESSING
# 615                    WAYNE SEMINOFF COMPANY
# 677                              MOGA GROWERS
# 343                           AAA BIO-DYNAMIC
# 544                    GREEN BLUFF GREENHOUSE
# 253                        THORJON RUSSELL-J1
# 214                                ROCKGARDEN
# 19                        THE RETAIL POT SHOP
# 499                                      STAT
# 281                            FIREWEED FARMS
# 892                                       RJL
# 18                                   HIGHROLR
# 701                     THE CANNABIS SEED CO.
# ..                                        ...
# 2                                    SOLSTICE
# 136                              SOLSTICE PRO
# 732                              SOLSTICE CON
# 961                           BIG RIDGE FARMS
# 301                      SWEET NIRVANA BAKERY
# 947                           BIG RIDGE FARMS
# 692                          8 BALL BARRISTER
# 199                     8 BALL BARRISTER, LLC
# 442                          THE BLACK MARKET
# 441                             FC PRODUCER-1
# 222                            FC PROCESSOR-2
# 837                            FC PROCESSOR-3
# 317                                 CANNAZONE
# 326                                 CANNAZONE
# 896                                 CANNAZONE
# 223                               THE HERBERY
# 491                               THE HERBERY
# 413                               THE HERBERY
# 394                          ORIGINS CANNABIS
# 505                          ORIGINS CANNABIS
# 359                          ORIGINS CANNABIS
# 889                                   BUD HUT
# 969                                    BUDHUT
# 676                          PABLO & CO., LLC
# 42                     2020 SOLUTIONS EPHRATA
# 324                  2020 SOLUTIONS SOAP LAKE
# 286                    2020 SOLUTIONS EDMONDS
# 663                    DISCOVERY BAY CANNABIS
# 714              PUGET SOUND CANNABIS COMPANY
# 384         WASHINGTON STATE CANNABIS COMPANY
#
#                                                  type        ubi  \
# 811  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  600128226
# 545  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  600314288
# 657     MARIJUANA PRODUCER TIER 3/MARIJUANA PROCESSOR  600369641
# 174     MARIJUANA PRODUCER TIER 1/MARIJUANA PROCESSOR  600385770
# 333     MARIJUANA PRODUCER TIER 2/MARIJUANA PROCESSOR  600435277
# 406     MARIJUANA PRODUCER TIER 1/MARIJUANA PROCESSOR  600449039
# 834     MARIJUANA PRODUCER TIER 2/MARIJUANA PROCESSOR  600497647
# 643     MARIJUANA PRODUCER TIER 3/MARIJUANA PROCESSOR  600505938
# 27      MARIJUANA PRODUCER TIER 2/MARIJUANA PROCESSOR  600519153
# 684                               MARIJUANA PROCESSOR  600578588
# 57                                 MARIJUANA RETAILER  600644801
# 686     MARIJUANA PRODUCER TIER 3/MARIJUANA PROCESSOR  600647707
# 540     MARIJUANA PRODUCER TIER 1/MARIJUANA PROCESSOR  601078913
# 168     MARIJUANA PRODUCER TIER 3/MARIJUANA PROCESSOR  601126223
# 827     MARIJUANA PRODUCER TIER 1/MARIJUANA PROCESSOR  601172971
# 195     MARIJUANA PRODUCER TIER 2/MARIJUANA PROCESSOR  601228738
# 985     MARIJUANA PRODUCER TIER 2/MARIJUANA PROCESSOR  601280167
# 542     MARIJUANA PRODUCER TIER 3/MARIJUANA PROCESSOR  601358843
# 615  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  601445386
# 677     MARIJUANA PRODUCER TIER 3/MARIJUANA PROCESSOR  601447135
# 343                         MARIJUANA PRODUCER TIER 1  601488292
# 544     MARIJUANA PRODUCER TIER 1/MARIJUANA PROCESSOR  601530853
# 253                         MARIJUANA PRODUCER TIER 3  601544408
# 214     MARIJUANA PRODUCER TIER 1/MARIJUANA PROCESSOR  601603333
# 19                                 MARIJUANA RETAILER  601636755
# 499     MARIJUANA PRODUCER TIER 1/MARIJUANA PROCESSOR  601661618
# 281                         MARIJUANA PRODUCER TIER 3  601673067
# 892     MARIJUANA PRODUCER TIER 1/MARIJUANA PROCESSOR  601680455
# 18      MARIJUANA PRODUCER TIER 1/MARIJUANA PROCESSOR  601777115
# 701                         MARIJUANA PRODUCER TIER 2  601825884
# ..                                                ...        ...
# 2                           MARIJUANA PRODUCER TIER 3  603132711
# 136                               MARIJUANA PROCESSOR  603132711
# 732                               MARIJUANA PROCESSOR  603132711
# 961     MARIJUANA PRODUCER TIER 3/MARIJUANA PROCESSOR  603298919
# 301                               MARIJUANA PROCESSOR  603298919
# 947                               MARIJUANA PROCESSOR  603298919
# 692  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603347956
# 199  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603347956
# 442  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603347956
# 441     MARIJUANA PRODUCER TIER 3/MARIJUANA PROCESSOR  603349172
# 222                               MARIJUANA PROCESSOR  603349172
# 837                               MARIJUANA PROCESSOR  603349172
# 317  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603354800
# 326  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603354800
# 896  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603354800
# 223  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603355031
# 491  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603355031
# 413  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603355031
# 394  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603562439
# 505  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603562439
# 359  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603562439
# 889  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603569959
# 969  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603569959
# 676  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603569959
# 42   MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603572346
# 324  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603572346
# 286  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603572346
# 663  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603585993
# 714  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603585993
# 384  MARIJUANA RETAILER/MEDICAL MARIJUANA ENDORSEMENT  603585993
#
#     ubi_business_id ubi_location  ubi_licenses
# 811             001         0001             1
# 545             001         0001             1
# 657             001         0002             1
# 174             001         0002             1
# 333             001         0003             1
# 406             001         0002             1
# 834             001         0002             1
# 643             001         0003             1
# 27              001         0002             1
# 684             001         0002             1
# 57              001         0004             1
# 686             001         0004             1
# 540             002         0002             1
# 168             001         0003             1
# 827             001         0003             1
# 195             001         0002             1
# 985             001         0001             1
# 542             001         0003             1
# 615             001         0002             1
# 677             001         0002             1
# 343             001         0003             1
# 544             001         0005             1
# 253             001         0002             1
# 214             002         0001             1
# 19              001         0002             1
# 499             002         0003             1
# 281             001         0002             1
# 892             001         0002             1
# 18              001         0002             1
# 701             001         0003             1
# ..              ...          ...           ...
# 2               001         0003             3
# 136             001         0006             3
# 732             001         0007             3
# 961             001         0002             3
# 301             001         0005             3
# 947             001         0006             3
# 692             001         0004             3
# 199             001         0005             3
# 442             001         0006             3
# 441             001         0002             3
# 222             001         0003             3
# 837             001         0004             3
# 317             001         0002             3
# 326             001         0003             3
# 896             001         0004             3
# 223             001         0001             3
# 491             001         0002             3
# 413             001         0004             3
# 394             001         0001             3
# 505             001         0003             3
# 359             001         0004             3
# 889             001         0001             3
# 969             001         0002             3
# 676             001         0004             3
# 42              001         0001             3
# 324             001         0002             3
# 286             001         0003             3
# 663             001         0001             3
# 714             001         0002             3
# 384             001         0003             3
#
# [1000 rows x 6 columns]
